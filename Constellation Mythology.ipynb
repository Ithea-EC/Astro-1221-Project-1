# %% [markdown]
# # Constellation Mythology
#
# This notebook explores the fascinating stories and legends behind the constellations visible in the night sky.
#
# ## Overview
#
# Constellations have been used for navigation, storytelling, and cultural significance for thousands of years. This notebook will explore:
# 1. The mythology and stories behind major constellations
# 2. The stars that make up these constellations
# 3. Cultural variations in constellation interpretations
# 4. Visualizations of constellation patterns

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
import matplotlib.patches as mpatches

# Set up matplotlib for better quality figures
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 14
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['axes.titlesize'] = 18

x=np.random.rand(30)
y=np.random.rand(30)

fig, ax = plt.subplots()
ax.scatter(x,y, s=20, c='b', marker='o')
ax.set_title("Constellation map")
# Out:
# Text(0.5, 1.0, 'Constellation map')
